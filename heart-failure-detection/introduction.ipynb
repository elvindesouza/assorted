# %%
from time import sleep
from pathlib import Path
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv("heart_failure.csv")

# %% [markdown]
# # Cursory glance at the dataset

# %%
df
# Out:
#      srno   age anaemia  creatinine_phosphokinase diabetes  ejection_fraction  \
# 0       0  75.0      No                       582       No                 20
# 1       1  55.0      No                      7861       No                 38
# 2       2  65.0      No                       146       No                 20
# 3       3  50.0     Yes                       111       No                 20
# 4       4  65.0     Yes                       160      Yes                 20
# ..    ...   ...     ...                       ...      ...                ...
# 294   294  62.0      No                        61      Yes                 38
# 295   295  55.0      No                      1820       No                 38
# 296   296  45.0      No                      2060      Yes                 60
# 297   297  45.0      No                      2413       No                 38
# 298   298  50.0      No                       196       No                 45
#
#     high_blood_pressure  platelets  serum_creatinine  serum_sodium     sex  \
# 0                   Yes  265000.00               1.9           130    Male
# 1                    No  263358.03               1.1           136    Male
# 2                    No  162000.00               1.3           129    Male
# 3                    No  210000.00               1.9           137    Male
# 4                    No  327000.00               2.7           116  Female
# ..                  ...        ...               ...           ...     ...
# 294                 Yes  155000.00               1.1           143    Male
# 295                  No  270000.00               1.2           139  Female
# 296                  No  742000.00               0.8           138  Female
# 297                  No  140000.00               1.4           140    Male
# 298                  No  395000.00               1.6           136    Male
#
#     smoking  time  DEATH_EVENT
# 0        No     4            1
# 1        No     6            1
# 2       Yes     7            1
# 3        No     7            1
# 4        No     8            1
# ..      ...   ...          ...
# 294     Yes   270            0
# 295      No   271            0
# 296      No   278            0
# 297     Yes   280            0
# 298     Yes   285            0
#
# [299 rows x 14 columns]

# %%
df.describe()
# Out:
#              srno         age  creatinine_phosphokinase  ejection_fraction  \
# count  299.000000  299.000000                299.000000         299.000000
# mean   149.000000   60.833893                581.839465          38.083612
# std     86.458082   11.894809                970.287881          11.834841
# min      0.000000   40.000000                 23.000000          14.000000
# 25%     74.500000   51.000000                116.500000          30.000000
# 50%    149.000000   60.000000                250.000000          38.000000
# 75%    223.500000   70.000000                582.000000          45.000000
# max    298.000000   95.000000               7861.000000          80.000000
#
#            platelets  serum_creatinine  serum_sodium        time  DEATH_EVENT
# count     299.000000         299.00000    299.000000  299.000000    299.00000
# mean   263358.029264           1.39388    136.625418  130.260870      0.32107
# std     97804.236869           1.03451      4.412477   77.614208      0.46767
# min     25100.000000           0.50000    113.000000    4.000000      0.00000
# 25%    212500.000000           0.90000    134.000000   73.000000      0.00000
# 50%    262000.000000           1.10000    137.000000  115.000000      0.00000
# 75%    303500.000000           1.40000    140.000000  203.000000      1.00000
# max    850000.000000           9.40000    148.000000  285.000000      1.00000

# %%
df.head
# Out:
# <bound method NDFrame.head of      srno   age anaemia  creatinine_phosphokinase diabetes  ejection_fraction  \
# 0       0  75.0      No                       582       No                 20
# 1       1  55.0      No                      7861       No                 38
# 2       2  65.0      No                       146       No                 20
# 3       3  50.0     Yes                       111       No                 20
# 4       4  65.0     Yes                       160      Yes                 20
# ..    ...   ...     ...                       ...      ...                ...
# 294   294  62.0      No                        61      Yes                 38
# 295   295  55.0      No                      1820       No                 38
# 296   296  45.0      No                      2060      Yes                 60
# 297   297  45.0      No                      2413       No                 38
# 298   298  50.0      No                       196       No                 45
#
#     high_blood_pressure  platelets  serum_creatinine  serum_sodium     sex  \
# 0                   Yes  265000.00               1.9           130    Male
# 1                    No  263358.03               1.1           136    Male
# 2                    No  162000.00               1.3           129    Male
# 3                    No  210000.00               1.9           137    Male
# 4                    No  327000.00               2.7           116  Female
# ..                  ...        ...               ...           ...     ...
# 294                 Yes  155000.00               1.1           143    Male
# 295                  No  270000.00               1.2           139  Female
# 296                  No  742000.00               0.8           138  Female
# 297                  No  140000.00               1.4           140    Male
# 298                  No  395000.00               1.6           136    Male
#
#     smoking  time  DEATH_EVENT
# 0        No     4            1
# 1        No     6            1
# 2       Yes     7            1
# 3        No     7            1
# 4        No     8            1
# ..      ...   ...          ...
# 294     Yes   270            0
# 295      No   271            0
# 296      No   278            0
# 297     Yes   280            0
# 298     Yes   285            0
#
# [299 rows x 14 columns]>

# %% [markdown]
# # Trying out different visualizations

# %%
df["platelets"].plot(kind="hist")
print(df.columns)

mean = df["platelets"].mean()
median = df["platelets"].median()
mode = df["platelets"].mode()
print(mean, median, mode)

ratio = df["sex"].value_counts()
print(ratio)

print(df["creatinine_phosphokinase"].describe())

plt.show()
# Out:
# Index(['srno', 'age', 'anaemia', 'creatinine_phosphokinase', 'diabetes',
#        'ejection_fraction', 'high_blood_pressure', 'platelets',
#        'serum_creatinine', 'serum_sodium', 'sex', 'smoking', 'time',
#        'DEATH_EVENT'],
#       dtype='object')
# 263358.02926421404 262000.0 0    263358.03
# dtype: float64
# Male      194
# Female    105
# Name: sex, dtype: int64
# count     299.000000
# mean      581.839465
# std       970.287881
# min        23.000000
# 25%       116.500000
# 50%       250.000000
# 75%       582.000000
# max      7861.000000
# Name: creatinine_phosphokinase, dtype: float64

# %%
a = pd.DataFrame(df["platelets"].to_numpy())
a.plot.hist(stacked=True, title="Platelet count distribution in dataset")
# print(df[1:].describe())


plt.show()

# %%
print(df.columns)
# df['serum_creatinine'].value_counts().plot(kind="bar")
df.groupby("serum_creatinine").size().plot(
    kind="bar", title="Serum creaitinine distribution in dataset"
)
# a=pd.DataFrame(df.to_numpy()  )

# a.plot.bar(stacked=True)
print(df[1:].describe())


plt.show()
# Out:
# Index(['srno', 'age', 'anaemia', 'creatinine_phosphokinase', 'diabetes',
#        'ejection_fraction', 'high_blood_pressure', 'platelets',
#        'serum_creatinine', 'serum_sodium', 'sex', 'smoking', 'time',
#        'DEATH_EVENT'],
#       dtype='object')
#              srno         age  creatinine_phosphokinase  ejection_fraction  \
# count  298.000000  298.000000                298.000000         298.000000
# mean   149.500000   60.786356                581.838926          38.144295
# std     86.169407   11.886333                971.919989          11.808060
# min      1.000000   40.000000                 23.000000          14.000000
# 25%     75.250000   51.000000                115.750000          30.000000
# 50%    149.500000   60.000000                249.500000          38.000000
# 75%    223.750000   70.000000                582.000000          45.000000
# max    298.000000   95.000000               7861.000000          80.000000
#
#            platelets  serum_creatinine  serum_sodium        time  DEATH_EVENT
# count     298.000000        298.000000    298.000000  298.000000   298.000000
# mean   263352.519295          1.392181    136.647651  130.684564     0.318792
# std     97968.705617          1.035833      4.403092   77.397621     0.466792
# min     25100.000000          0.500000    113.000000    6.000000     0.000000
# 25%    212250.000000          0.900000    134.000000   73.250000     0.000000
# 50%    262000.000000          1.100000    137.000000  115.000000     0.000000
# 75%    303750.000000          1.400000    140.000000  204.000000     1.000000
# max    850000.000000          9.400000    148.000000  285.000000     1.000000

# %%
df[1:].describe()
# Out:
#              srno         age  creatinine_phosphokinase  ejection_fraction  \
# count  298.000000  298.000000                298.000000         298.000000
# mean   149.500000   60.786356                581.838926          38.144295
# std     86.169407   11.886333                971.919989          11.808060
# min      1.000000   40.000000                 23.000000          14.000000
# 25%     75.250000   51.000000                115.750000          30.000000
# 50%    149.500000   60.000000                249.500000          38.000000
# 75%    223.750000   70.000000                582.000000          45.000000
# max    298.000000   95.000000               7861.000000          80.000000
#
#            platelets  serum_creatinine  serum_sodium        time  DEATH_EVENT
# count     298.000000        298.000000    298.000000  298.000000   298.000000
# mean   263352.519295          1.392181    136.647651  130.684564     0.318792
# std     97968.705617          1.035833      4.403092   77.397621     0.466792
# min     25100.000000          0.500000    113.000000    6.000000     0.000000
# 25%    212250.000000          0.900000    134.000000   73.250000     0.000000
# 50%    262000.000000          1.100000    137.000000  115.000000     0.000000
# 75%    303750.000000          1.400000    140.000000  204.000000     1.000000
# max    850000.000000          9.400000    148.000000  285.000000     1.000000
